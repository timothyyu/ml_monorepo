# %%
def remove_firstline(oldfile) :
    with open(oldfile,'r') as f:
        newfile = oldfile + '.1'
        print(newfile)
        with open(newfile,'a') as f1:
            f.next() # skip header line
            for line in f:
                f1.write(line)
            f1.close()

# %%
### handling the stock/index csv data
import glob, os

def handle_index_data() :
    os.chdir("/home/jianbo/Data/index_data")
    for file in glob.glob("*.csv"):
        print(file)
        remove_firstline(file)
        os.remove(file)

def handle_stock_data() :
    os.chdir("/home/jianbo/Data/stock_data")
    for file in glob.glob("*.csv"):
        print(file)
        remove_firstline(file)
        os.remove(file)

# %% [markdown]
# # Import historical price data into database

# %%
import csv
#import MySQLdb
import glob, os
import pymongo

def get_mysql_conn() :
    # init DB
    mydb = MySQLdb.connect(host='188.166.179.144',
        user='root',
        passwd='eth@2002',
        db='darwin')
    return mydb

def get_mongo_conn() :
    try :
        mgdb = pymongo.MongoClient('localhost', 27012)
        print 'Successfull connected!'
    except:
        print 'Failed to connect'
        mgdb = NULL
    return mgdb
    
mysql_db = get_mysql_conn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2c1fda3ed4ab> in <module>()
#      21     return mgdb
#      22
# ---> 23 mysql_db = get_mysql_conn()
#
# <ipython-input-2-2c1fda3ed4ab> in get_mysql_conn()
#       6 def get_mysql_conn() :
#       7     # init DB
# ----> 8     mydb = MySQLdb.connect(host='188.166.179.144',
#       9         user='root',
#      10         passwd='eth@2002',
#
# NameError: global name 'MySQLdb' is not defined

# %% [markdown]
# # 1. Loading daily stock price data into mysql db

# %%
# init DB
def load_daily_price_into_db() :
    mydb = get_db_conn()
    cursor = mydb.cursor()

    # change the directory to stock data
    os.chdir('/home/jianbo/Data/stock_data')
    for stock_file in glob.glob('*.csv') :
        csv_data = csv.reader(file(stock_file))
        print "loading file " + stock_file
        count = 0

        for row in csv_data:
            if count == 0:
                count = count + 1
                continue
            try:
                cursor.execute('INSERT INTO Stock_Price_Daily(code,date,open,high,low,close, price_change,volume,money,traded_market_value,market_value, turnover,adjust_price,report_type,report_date,PE_TTM,PS_TTM,PC_TTM,PB) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)', row)
                mydb.commit()
            except:
                mydb.rollback()
        os.remove(stock_file)


    # close the connection
    mydb.close()

# %% [markdown]
# # Import Stock Fundamental Information

# %%
import tushare as ts
basics = ts.get_stock_basics()

# %%
for row in basics.iterrows():
    print row
# Out:
# ('000001', name                       平安银行
# industry                     银行
# area                         深圳
# pe                         7.51
# outstanding         1.18041e+06
# totals              1.43087e+06
# totalAssets         2.59906e+08
# liquidAssets                  0
# fixedAssets              440600
# reserved             5.9326e+06
# reservedPerShare           4.15
# esp                        1.27
# bvps                      10.98
# pb                         1.13
# timeToMarket           19910403
# Name: 000001, dtype: object)
# ('000002', name                      万  科Ａ
# industry                   全国地产
# area                         深圳
# pe                         29.5
# outstanding              970679
# totals              1.10371e+06
# totalAssets         5.70793e+07
# liquidAssets        5.20001e+07
# fixedAssets              404016
# reserved                 834237
# reservedPerShare           0.76
# esp                       0.621
# bvps                       8.05
# pb                         3.04
# timeToMarket           19910129
# Name: 000002, dtype: object)
# ('000004', name                    国农科技
# industry                生物制药
# area                      深圳
# pe                   1310.21
# outstanding          8387.54
# totals               8397.66
# totalAssets          35863.9
# liquidAssets         28597.3
# fixedAssets          3792.01
# reserved               66.45
# reservedPerShare        0.01
# esp                    0.028
# bvps                    0.99
# pb                     50.18
# timeToMarket        19910114
# Name: 000004, dtype: object)
# ('000005', name                    世纪星源
# industry                区域地产
# area                      深圳
# pe                         0
# outstanding          91374.3
# totals               91433.4
# totalAssets           133659
# liquidAssets         22092.8
# fixedAssets          2413.78
# reserved               26977
# reservedPerShare         0.3
# esp                   -0.033
# bvps                     0.7
# pb                     14.82
# timeToMarket        19901210
# Name: 000005, dtype: object)
# ('000006', name                       深振业Ａ
# industry                   区域地产
# area                         深圳
# pe                        44.11
# outstanding              134149
# totals                   135000
# totalAssets         1.23869e+06
# liquidAssets         1.0154e+06
# fixedAssets              362.29
# reserved                48432.2
# reservedPerShare           0.36
# esp                       0.205
# bvps                       3.15
# pb                         3.83
# timeToMarket           19920427
# Name: 000006, dtype: object)
# ('000007', name                    零七股份
# industry                酒店餐饮
# area                      深圳
# pe                         0
# outstanding          20588.7
# totals               23096.5
# totalAssets          52680.4
# liquidAssets         33271.5
# fixedAssets          7281.37
# reserved             42324.1
# reservedPerShare        1.83
# esp                   -0.051
# bvps                    1.48
# pb                      16.1
# timeToMarket        19920413
# Name: 000007, dtype: object)
# ('000008', name                    神州高铁
# industry                 综合类
# area                      北京
# pe                    225.57
# outstanding          64072.8
# totals                240943
# totalAssets           335976
# liquidAssets          146185
# fixedAssets            41419
# reserved             31871.7
# reservedPerShare        0.13
# esp                     0.04
# bvps                    1.17
# pb                     10.23
# timeToMarket        19920507
# Name: 000008, dtype: object)
# ('000009', name                       中国宝安
# industry                   全国地产
# area                         深圳
# pe                        32.95
# outstanding              148967
# totals                   159211
# totalAssets         1.66613e+06
# liquidAssets        1.16205e+06
# fixedAssets              168928
# reserved                52228.1
# reservedPerShare           0.33
# esp                       0.427
# bvps                       2.81
# pb                         6.68
# timeToMarket           19910625
# Name: 000009, dtype: object)
# ('000010', name                     深华新
# industry                建筑施工
# area                      北京
# pe                    2030.2
# outstanding            40793
# totals               70561.3
# totalAssets           190286
# liquidAssets         55589.3
# fixedAssets          4303.23
# reserved               12939
# reservedPerShare        0.18
# esp                    0.004
# bvps                    0.93
# pb                     11.36
# timeToMarket        19951027
# Name: 000010, dtype: object)
# ('000011', name                    深物业A
# industry                区域地产
# area                      深圳
# pe                    145.87
# outstanding          17586.2
# totals               59597.9
# totalAssets           400862
# liquidAssets          331031
# fixedAssets           6805.2
# reserved             11995.1
# reservedPerShare         0.2
# esp                    0.078
# bvps                    3.33
# pb                      4.55
# timeToMarket        19920330
# Name: 000011, dtype: object)
# ('000012', name                      南  玻Ａ
# industry                     玻璃
# area                         深圳
# pe                        57.75
# outstanding              130255
# totals                   207534
# totalAssets          1.5235e+06
# liquidAssets             187161
# fixedAssets         1.00828e+06
# reserved                 126104
# reservedPerShare           0.61
# esp                        0.19
# bvps                       3.71
# pb                         3.94
# timeToMarket           19920228
# Name: 000012, dtype: object)
# ('000014', name                    沙河股份
# industry                全国地产
# area                      深圳
# pe                         0
# outstanding          20170.5
# totals               20170.5
# totalAssets           214252
# liquidAssets          194648
# fixedAssets          2105.12
# reserved              996.57
# reservedPerShare        0.05
# esp                   -0.005
# bvps                    3.28
# pb                       7.2
# timeToMarket        19920602
# Name: 000014, dtype: object)
# ('000016', name                       深康佳Ａ
# industry                   家用电器
# area                         深圳
# pe                            0
# outstanding              119983
# totals                   240795
# totalAssets         1.64143e+06
# liquidAssets        1.28298e+06
# fixedAssets              173618
# reserved                8790.45
# reservedPerShare           0.04
# esp                      -0.354
# bvps                       1.34
# pb                         5.42
# timeToMarket           19920327
# Name: 000016, dtype: object)
# ('000017', name                    深中华A
# industry                文教休闲
# area                      深圳
# pe                   11503.9
# outstanding          30297.9
# totals               55134.8
# totalAssets          6806.66
# liquidAssets         6305.91
# fixedAssets           104.21
# reserved             62783.4
# reservedPerShare        1.14
# esp                    0.001
# bvps                    0.02
# pb                     663.4
# timeToMarket        19920331
# Name: 000017, dtype: object)
# ('000018', name                    神州长城
# industry                装修装饰
# area                      深圳
# pe                     64.75
# outstanding          9972.04
# totals               44690.7
# totalAssets           379740
# liquidAssets          364504
# fixedAssets          3756.59
# reserved             -255.16
# reservedPerShare       -0.01
# esp                     1.43
# bvps                    7.35
# pb                      6.37
# timeToMarket        19920616
# Name: 000018, dtype: object)
# ('000019', name                    深深宝Ａ
# industry                 软饮料
# area                      深圳
# pe                         0
# outstanding          25225.2
# totals                 30108
# totalAssets           109560
# liquidAssets         48753.5
# fixedAssets          38168.5
# reserved             51818.6
# reservedPerShare        1.72
# esp                   -0.027
# bvps                     3.2
# pb                      5.63
# timeToMarket        19921012
# Name: 000019, dtype: object)
# ('000020', name                    深华发Ａ
# industry                 元器件
# area                      深圳
# pe                    339.36
# outstanding          6467.54
# totals               28316.1
# totalAssets           116594
# liquidAssets         88803.4
# fixedAssets          19114.5
# reserved             10949.7
# reservedPerShare        0.39
# esp                    0.071
# bvps                    1.06
# pb                     30.02
# timeToMarket        19920428
# Name: 000020, dtype: object)
# ('000021', name                        深科技
# industry                   电脑设备
# area                         深圳
# pe                        98.21
# outstanding              146981
# totals                   147126
# totalAssets         1.48511e+06
# liquidAssets        1.10794e+06
# fixedAssets              179380
# reserved                66241.7
# reservedPerShare           0.45
# esp                       0.095
# bvps                       3.46
# pb                         3.61
# timeToMarket           19940202
# Name: 000021, dtype: object)
# ('000022', name                    深赤湾Ａ
# industry                  港口
# area                      深圳
# pe                     23.13
# outstanding          46486.7
# totals               64476.4
# totalAssets           683380
# liquidAssets         74113.2
# fixedAssets           317678
# reserved             16340.2
# reservedPerShare        0.25
# esp                    0.648
# bvps                    6.71
# pb                      2.98
# timeToMarket        19930505
# Name: 000022, dtype: object)
# ('000023', name                    深天地Ａ
# industry                建筑施工
# area                      深圳
# pe                    116.62
# outstanding          13875.6
# totals               13875.6
# totalAssets           153004
# liquidAssets          136764
# fixedAssets          12430.9
# reserved             10252.6
# reservedPerShare        0.74
# esp                    0.196
# bvps                    2.77
# pb                     11.03
# timeToMarket        19930429
# Name: 000023, dtype: object)
# ('000024', name                       招商地产
# industry                   全国地产
# area                         深圳
# pe                        35.26
# outstanding              102642
# totals                   257595
# totalAssets         1.81418e+07
# liquidAssets        1.69258e+07
# fixedAssets              178645
# reserved                 889972
# reservedPerShare           3.45
# esp                       0.861
# bvps                      12.76
# pb                         3.17
# timeToMarket           19930607
# Name: 000024, dtype: object)
# ('000025', name                   特  力Ａ
# industry                汽车服务
# area                      深圳
# pe                   1098.41
# outstanding          17929.5
# totals               29728.2
# totalAssets           113085
# liquidAssets           39120
# fixedAssets          13773.5
# reserved             56419.3
# reservedPerShare         1.9
# esp                     0.07
# bvps                    2.84
# pb                     32.44
# timeToMarket        19930621
# Name: 000025, dtype: object)
# ('000026', name                    飞亚达Ａ
# industry                其他商业
# area                      深圳
# pe                     46.72
# outstanding            31107
# totals               39276.8
# totalAssets           385233
# liquidAssets          282341
# fixedAssets          36442.3
# reserved             52550.8
# reservedPerShare        1.34
# esp                    0.271
# bvps                    4.34
# pb                       3.9
# timeToMarket        19930603
# Name: 000026, dtype: object)
# ('000027', name                       深圳能源
# industry                   火力发电
# area                         深圳
# pe                        19.11
# outstanding              143752
# totals                   396449
# totalAssets         4.63144e+06
# liquidAssets        1.36069e+06
# fixedAssets         1.50473e+06
# reserved                 431470
# reservedPerShare           1.09
# esp                       0.401
# bvps                       5.26
# pb                         1.94
# timeToMarket           19930903
# Name: 000027, dtype: object)
# ('000028', name                       国药一致
# industry                   医药商业
# area                         深圳
# pe                        31.34
# outstanding             23326.2
# totals                  36263.2
# totalAssets         1.42989e+06
# liquidAssets        1.24117e+06
# fixedAssets             77500.8
# reserved                 186389
# reservedPerShare           5.14
# esp                       1.583
# bvps                      14.52
# pb                         4.56
# timeToMarket           19930809
# Name: 000028, dtype: object)
# ('000029', name                    深深房Ａ
# industry                区域地产
# area                      深圳
# pe                     43.65
# outstanding            89166
# totals                101166
# totalAssets           452243
# liquidAssets          393330
# fixedAssets          4995.51
# reserved             97824.5
# reservedPerShare        0.97
# esp                    0.231
# bvps                    2.24
# pb                      6.02
# timeToMarket        19930915
# Name: 000029, dtype: object)
# ('000030', name                    富奥股份
# industry                汽车配件
# area                      吉林
# pe                     25.39
# outstanding          56056.2
# totals                129325
# totalAssets           742379
# liquidAssets          341162
# fixedAssets           131678
# reserved             52338.8
# reservedPerShare         0.4
# esp                    0.281
# bvps                    3.52
# pb                       2.7
# timeToMarket        19930929
# Name: 000030, dtype: object)
# ('000031', name                       中粮地产
# industry                   全国地产
# area                         深圳
# pe                        36.95
# outstanding              181372
# totals                   181373
# totalAssets         5.51289e+06
# liquidAssets        4.99264e+06
# fixedAssets             57170.6
# reserved                27988.3
# reservedPerShare           0.15
# esp                       0.296
# bvps                       3.25
# pb                         4.48
# timeToMarket           19931008
# Name: 000031, dtype: object)
# ('000032', name                    深桑达Ａ
# industry                 元器件
# area                      深圳
# pe                         0
# outstanding          23286.3
# totals               23286.4
# totalAssets           130692
# liquidAssets         79460.9
# fixedAssets          5725.66
# reserved             20723.8
# reservedPerShare        0.89
# esp                   -0.014
# bvps                    3.76
# pb                      6.91
# timeToMarket        19931028
# Name: 000032, dtype: object)
# ('000034', name                    深信泰丰
# industry                 综合类
# area                      深圳
# pe                    283.01
# outstanding          34006.4
# totals               35797.3
# totalAssets          44538.9
# liquidAssets           22802
# fixedAssets          5683.41
# reserved             64072.7
# reservedPerShare        1.79
# esp                    0.074
# bvps                    0.54
# pb                     52.07
# timeToMarket        19940509
# Name: 000034, dtype: object)
# ('000035', name                    中国天楹
# industry                环境保护
# area                      江苏
# pe                     58.95
# outstanding          40355.1
# totals               61927.9
# totalAssets           405636
# liquidAssets           69054
# fixedAssets            71533
# reserved             94385.4
# reservedPerShare        1.52
# esp                    0.195
# bvps                    2.81
# pb                      5.45
# timeToMarket        19940408
# Name: 000035, dtype: object)
# ('000036', name                    华联控股
# industry                全国地产
# area                      深圳
# pe                         0
# outstanding           112388
# totals                114049
# totalAssets           554060
# liquidAssets          447853
# fixedAssets          28562.2
# reserved               14372
# reservedPerShare        0.13
# esp                   -0.002
# bvps                    1.67
# pb                      5.45
# timeToMarket        19940617
# Name: 000036, dtype: object)
# ('000037', name                    深南电Ａ
# industry                火力发电
# area                      深圳
# pe                         0
# outstanding          33889.5
# totals               60276.3
# totalAssets           513349
# liquidAssets          315953
# fixedAssets           177720
# reserved             36275.1
# reservedPerShare         0.6
# esp                   -0.121
# bvps                    1.99
# pb                      6.95
# timeToMarket        19940701
# Name: 000037, dtype: object)
# ('000038', name                     深大通
# industry                区域地产
# area                      深圳
# pe                   3701.24
# outstanding          3773.13
# totals               9622.79
# totalAssets          68993.5
# liquidAssets         68107.8
# fixedAssets             5.09
# reserved             2234.82
# reservedPerShare        0.23
# esp                    0.012
# bvps                    1.15
# pb                     49.35
# timeToMarket        19940808
# Name: 000038, dtype: object)
# ('000039', name                       中集集团
# industry                   轻工机械
# area                         深圳
# pe                        26.49
# outstanding              125914
# totals                   269025
# totalAssets         1.02992e+07
# liquidAssets        4.78566e+06
# fixedAssets         1.91366e+06
# reserved                 108938
# reservedPerShare            0.4
# esp                       0.641
# bvps                       9.57
# pb                         2.37
# timeToMarket           19940408
# Name: 000039, dtype: object)
# ('000040', name                    宝安地产
# industry                全国地产
# area                      深圳
# pe                    168.49
# outstanding          46458.8
# totals               46959.3
# totalAssets           478158
# liquidAssets          448364
# fixedAssets          6806.12
# reserved             27375.2
# reservedPerShare        0.58
# esp                    0.067
# bvps                    2.75
# pb                      5.48
# timeToMarket        19940808
# Name: 000040, dtype: object)
# ('000042', name                       中洲控股
# industry                   全国地产
# area                         深圳
# pe                        18.77
# outstanding             47878.3
# totals                  48823.5
# totalAssets         2.51714e+06
# liquidAssets        2.11768e+06
# fixedAssets             17480.8
# reserved                67530.5
# reservedPerShare           1.38
# esp                        0.86
# bvps                       7.66
# pb                         2.76
# timeToMarket           19940921
# Name: 000042, dtype: object)
# ('000043', name                       中航地产
# industry                   全国地产
# area                         深圳
# pe                            0
# outstanding             66696.1
# totals                  66696.1
# totalAssets         2.25535e+06
# liquidAssets        1.65231e+06
# fixedAssets             14168.1
# reserved                44552.9
# reservedPerShare           0.67
# esp                      -0.254
# bvps                        4.9
# pb                         2.51
# timeToMarket           19940928
# Name: 000043, dtype: object)
# ('000045', name                    深纺织Ａ
# industry                  纺织
# area                      深圳
# pe                    945.64
# outstanding          40556.4
# totals               50652.2
# totalAssets           282360
# liquidAssets          170652
# fixedAssets          77383.9
# reserved              158513
# reservedPerShare        3.13
# esp                    0.012
# bvps                    4.28
# pb                      3.59
# timeToMarket        19940815
# Name: 000045, dtype: object)
# ('000046', name                       泛海控股
# industry                   全国地产
# area                         深圳
# pe                         37.3
# outstanding              454933
# totals                   455731
# totalAssets         9.76388e+06
# liquidAssets        8.41396e+06
# fixedAssets             56870.9
# reserved                 197403
# reservedPerShare           0.43
# esp                       0.259
# bvps                       2.22
# pb                          5.8
# timeToMarket           19940912
# Name: 000046, dtype: object)
# ('000048', name                     康达尔
# industry                  饲料
# area                      深圳
# pe                     69.86
# outstanding          38606.8
# totals               39076.9
# totalAssets           201170
# liquidAssets          129174
# fixedAssets          33220.8
# reserved             4406.85
# reservedPerShare        0.11
# esp                    0.431
# bvps                    1.73
# pb                     23.16
# timeToMarket        19941101
# Name: 000048, dtype: object)
# ('000049', name                    德赛电池
# industry                电气设备
# area                      深圳
# pe                     50.64
# outstanding          20524.4
# totals               20524.4
# totalAssets           395844
# liquidAssets          357378
# fixedAssets          16379.9
# reserved              816.93
# reservedPerShare        0.04
# esp                    0.843
# bvps                    4.26
# pb                     13.37
# timeToMarket        19950320
# Name: 000049, dtype: object)
# ('000050', name                       深天马Ａ
# industry                    元器件
# area                         深圳
# pe                        54.35
# outstanding             94308.6
# totals                   113174
# totalAssets         1.72078e+06
# liquidAssets             677722
# fixedAssets              705036
# reserved                 696756
# reservedPerShare           6.16
# esp                       0.299
# bvps                       7.41
# pb                         2.93
# timeToMarket           19950315
# Name: 000050, dtype: object)
# ('000055', name                    方大集团
# industry                其他建材
# area                      深圳
# pe                     114.8
# outstanding          42017.9
# totals                 75691
# totalAssets           445227
# liquidAssets          341785
# fixedAssets          48826.6
# reserved             7909.92
# reservedPerShare         0.1
# esp                    0.095
# bvps                     1.7
# pb                      8.53
# timeToMarket        19960415
# Name: 000055, dtype: object)
# ('000056', name                    皇庭国际
# industry                房产服务
# area                      深圳
# pe                    487.81
# outstanding          14305.5
# totals               57389.2
# totalAssets           797773
# liquidAssets         22070.5
# fixedAssets           5764.1
# reserved              183001
# reservedPerShare        3.19
# esp                     0.09
# bvps                    8.69
# pb                      3.92
# timeToMarket        19960708
# Name: 000056, dtype: object)
# ('000058', name                   深 赛 格
# industry                 元器件
# area                      深圳
# pe                    165.33
# outstanding          53831.1
# totals               78479.9
# totalAssets           257319
# liquidAssets          133795
# fixedAssets          3771.63
# reserved             50654.3
# reservedPerShare        0.65
# esp                    0.054
# bvps                    1.84
# pb                      6.44
# timeToMarket        19961226
# Name: 000058, dtype: object)
# ('000059', name                      *ST华锦
# industry                   石油加工
# area                         辽宁
# pe                       143.05
# outstanding              120050
# totals                   159944
# totalAssets         3.02788e+06
# liquidAssets             978703
# fixedAssets         1.49629e+06
# reserved                 635282
# reservedPerShare           3.97
# esp                       0.043
# bvps                       5.39
# pb                         1.51
# timeToMarket           19970130
# Name: 000059, dtype: object)
# ('000060', name                       中金岭南
# industry                     铅锌
# area                         深圳
# pe                        244.6
# outstanding              206142
# totals                   221263
# totalAssets         1.56314e+06
# liquidAssets             425594
# fixedAssets              451785
# reserved                 147468
# reservedPerShare           0.67
# esp                       0.046
# bvps                        3.3
# pb                         4.51
# timeToMarket           19970123
# Name: 000060, dtype: object)
# ('000061', name                      农 产 品
# industry                   农业综合
# area                         深圳
# pe                       527.84
# outstanding              160768
# totals                   169696
# totalAssets         1.52294e+06
# liquidAssets             292686
# fixedAssets              295631
# reserved                 261351
# reservedPerShare           1.54
# esp                       0.027
# bvps                       2.86
# pb                         6.72
# timeToMarket           19970110
# Name: 000061, dtype: object)
# ('000062', name                    深圳华强
# industry                商贸代理
# area                      深圳
# pe                     95.96
# outstanding            66695
# totals               72131.7
# totalAssets           403064
# liquidAssets          153021
# fixedAssets          38446.4
# reserved               26.36
# reservedPerShare           0
# esp                    0.308
# bvps                    3.69
# pb                     10.68
# timeToMarket        19970130
# Name: 000062, dtype: object)
# ('000063', name                       中兴通讯
# industry                   通信设备
# area                         深圳
# pe                        22.58
# outstanding              336230
# totals                   412505
# totalAssets         1.16172e+07
# liquidAssets        9.12167e+06
# fixedAssets              732441
# reserved                 817093
# reservedPerShare           1.98
# esp                       0.631
# bvps                       6.46
# pb                         2.94
# timeToMarket           19971118
# Name: 000063, dtype: object)
# ('000065', name                    北方国际
# industry                建筑施工
# area                      深圳
# pe                     61.25
# outstanding          25340.2
# totals               27437.2
# totalAssets           622668
# liquidAssets          523882
# fixedAssets          13455.1
# reserved             91439.5
# reservedPerShare        3.33
# esp                     0.39
# bvps                    6.68
# pb                      4.57
# timeToMarket        19980605
# Name: 000065, dtype: object)
# ('000066', name                       长城电脑
# industry                   电脑设备
# area                         深圳
# pe                            0
# outstanding              132357
# totals                   132359
# totalAssets         4.12264e+06
# liquidAssets        3.18125e+06
# fixedAssets              335872
# reserved                74128.7
# reservedPerShare           0.56
# esp                      -0.103
# bvps                       1.88
# pb                        11.44
# timeToMarket           19970626
# Name: 000066, dtype: object)
# ('000068', name                   *ST华赛
# industry                 元器件
# area                      深圳
# pe                         0
# outstanding          89667.1
# totals                100667
# totalAssets          65088.2
# liquidAssets         33887.1
# fixedAssets          19689.4
# reserved              119427
# reservedPerShare        1.19
# esp                   -0.021
# bvps                    0.58
# pb                     23.08
# timeToMarket        19970611
# Name: 000068, dtype: object)
# ('000069', name                       华侨城Ａ
# industry                   旅游景点
# area                         深圳
# pe                        20.68
# outstanding              311246
# totals                   735399
# totalAssets         1.03145e+07
# liquidAssets        7.30446e+06
# fixedAssets         1.50822e+06
# reserved                61811.6
# reservedPerShare           0.08
# esp                       0.339
# bvps                       4.12
# pb                         2.27
# timeToMarket           19970910
# Name: 000069, dtype: object)
# ('000070', name                    特发信息
# industry                通信设备
# area                      深圳
# pe                    141.65
# outstanding          25857.6
# totals               31349.7
# totalAssets           285350
# liquidAssets          189211
# fixedAssets          46721.2
# reserved             60129.3
# reservedPerShare        1.92
# esp                    0.169
# bvps                    4.11
# pb                      7.76
# timeToMarket        20000511
# Name: 000070, dtype: object)
# ('000078', name                       海王生物
# industry                   生物制药
# area                         深圳
# pe                        36.19
# outstanding             73076.8
# totals                  75251.4
# totalAssets         1.21637e+06
# liquidAssets        1.09958e+06
# fixedAssets               40032
# reserved                 145523
# reservedPerShare           1.93
# esp                       0.466
# bvps                       2.43
# pb                         9.25
# timeToMarket           19981218
# Name: 000078, dtype: object)
# ('000088', name                   盐 田 港
# industry                  港口
# area                      深圳
# pe                     34.41
# outstanding           194215
# totals                194220
# totalAssets           760891
# liquidAssets          162338
# fixedAssets          15479.9
# reserved             71086.1
# reservedPerShare        0.37
# esp                    0.191
# bvps                    2.78
# pb                      3.16
# timeToMarket        19970728
# Name: 000088, dtype: object)
# ('000089', name                       深圳机场
# industry                     机场
# area                         深圳
# pe                        38.76
# outstanding              205067
# totals                   205077
# totalAssets         1.26536e+06
# liquidAssets             274097
# fixedAssets              771576
# reserved                 280275
# reservedPerShare           1.37
# esp                        0.18
# bvps                        4.9
# pb                         1.73
# timeToMarket           19980420
# Name: 000089, dtype: object)
# ('000090', name                       天健集团
# industry                   建筑施工
# area                         深圳
# pe                        46.71
# outstanding               55253
# totals                  85556.1
# totalAssets         1.28254e+06
# liquidAssets             967602
# fixedAssets             15368.7
# reserved                  75115
# reservedPerShare           0.88
# esp                       0.302
# bvps                       7.27
# pb                         2.58
# timeToMarket           19990721
# Name: 000090, dtype: object)
# ('000096', name                    广聚能源
# industry                石油贸易
# area                      深圳
# pe                     31.76
# outstanding          51084.8
# totals                 52800
# totalAssets           227931
# liquidAssets          129352
# fixedAssets          8194.63
# reserved             35111.4
# reservedPerShare        0.66
# esp                    0.399
# bvps                     3.9
# pb                      4.33
# timeToMarket        20000724
# Name: 000096, dtype: object)
# ('000099', name                    中信海直
# industry                  空运
# area                      深圳
# pe                     48.85
# outstanding            60607
# totals                 60607
# totalAssets           471244
# liquidAssets          144691
# fixedAssets           308207
# reserved              103327
# reservedPerShare         1.7
# esp                    0.238
# bvps                    4.61
# pb                      3.36
# timeToMarket        20000731
# Name: 000099, dtype: object)
# ('000100', name                     TCL 集团
# industry                   家用电器
# area                         广东
# pe                        19.63
# outstanding              899542
# totals              1.22245e+06
# totalAssets         1.17293e+07
# liquidAssets        6.50729e+06
# fixedAssets         2.39524e+06
# reserved                 530316
# reservedPerShare           0.43
# esp                        0.18
# bvps                       1.97
# pb                         2.25
# timeToMarket           20040130
# Name: 000100, dtype: object)
# ('000150', name                    宜华健康
# industry                医疗保健
# area                      广东
# pe                   13358.7
# outstanding            32400
# totals               44780.5
# totalAssets           431490
# liquidAssets          328215
# fixedAssets           5857.5
# reserved             98907.4
# reservedPerShare        2.21
# esp                    0.002
# bvps                    3.66
# pb                      9.97
# timeToMarket        20000807
# Name: 000150, dtype: object)
# ('000151', name                    中成股份
# industry                商贸代理
# area                      北京
# pe                     63.71
# outstanding          26654.4
# totals                 29598
# totalAssets           270061
# liquidAssets          249044
# fixedAssets          3397.01
# reserved             44202.7
# reservedPerShare        1.49
# esp                    0.289
# bvps                    3.24
# pb                      7.58
# timeToMarket        20000906
# Name: 000151, dtype: object)
# ('000153', name                    丰原药业
# industry                化学制药
# area                      安徽
# pe                     75.61
# outstanding          29664.5
# totals               31214.1
# totalAssets           229004
# liquidAssets         94251.7
# fixedAssets          58483.8
# reserved             49104.1
# reservedPerShare        1.57
# esp                    0.104
# bvps                    3.67
# pb                      2.84
# timeToMarket        20000920
# Name: 000153, dtype: object)
# ('000155', name                   *ST川化
# industry                农药化肥
# area                      四川
# pe                         0
# outstanding            47000
# totals                 47000
# totalAssets           121319
# liquidAssets         41283.7
# fixedAssets          44538.3
# reserved             81028.6
# reservedPerShare        1.72
# esp                   -0.357
# bvps                   -2.17
# pb                     -4.96
# timeToMarket        20000926
# Name: 000155, dtype: object)
# ('000156', name                       华数传媒
# industry                   影视音像
# area                         浙江
# pe                        92.45
# outstanding             54686.8
# totals                   143335
# totalAssets         1.23202e+06
# liquidAssets             729552
# fixedAssets              220082
# reserved                 620240
# reservedPerShare           4.33
# esp                        0.31
# bvps                       6.35
# pb                         5.46
# timeToMarket           20000906
# Name: 000156, dtype: object)
# ('000157', name                       中联重科
# industry                   工程机械
# area                         湖南
# pe                            0
# outstanding              626189
# totals                   770595
# totalAssets         9.81268e+06
# liquidAssets        7.89269e+06
# fixedAssets              744627
# reserved            1.31525e+06
# reservedPerShare           1.71
# esp                      -0.067
# bvps                       5.12
# pb                          1.1
# timeToMarket           20001012
# Name: 000157, dtype: object)
# ('000158', name                    常山股份
# industry                  纺织
# area                      河北
# pe                         0
# outstanding          71886.1
# totals                127144
# totalAssets           955712
# liquidAssets          495269
# fixedAssets           107717
# reserved              326592
# reservedPerShare        2.57
# esp                    -0.07
# bvps                    4.02
# pb                      5.31
# timeToMarket        20000724
# Name: 000158, dtype: object)
# ('000159', name                    国际实业
# industry                石油贸易
# area                      新疆
# pe                         0
# outstanding          48113.9
# totals               48113.9
# totalAssets           289514
# liquidAssets          185901
# fixedAssets          22280.5
# reserved             38753.1
# reservedPerShare        0.81
# esp                   -0.086
# bvps                    4.34
# pb                       2.1
# timeToMarket        20000926
# Name: 000159, dtype: object)
# ('000166', name                       申万宏源
# industry                     证券
# area                         新疆
# pe                        14.73
# outstanding              327825
# totals              1.48567e+06
# totalAssets          3.4971e+07
# liquidAssets                  0
# fixedAssets              125187
# reserved                 445381
# reservedPerShare            0.3
# esp                       0.565
# bvps                       3.13
# pb                         3.55
# timeToMarket           20150126
# Name: 000166, dtype: object)
# ('000301', name                    东方市场
# industry                 综合类
# area                      江苏
# pe                     41.53
# outstanding           121824
# totals                121824
# totalAssets           414260
# liquidAssets          108618
# fixedAssets          24209.8
# reserved             63657.8
# reservedPerShare        0.52
# esp                    0.112
# bvps                    2.63
# pb                      2.36
# timeToMarket        20000529
# Name: 000301, dtype: object)
# ('000333', name                       美的集团
# industry                   家用电器
# area                         广东
# pe                         9.34
# outstanding              223937
# totals                   426571
# totalAssets         1.34346e+07
# liquidAssets        9.93796e+06
# fixedAssets         1.86314e+06
# reserved            1.45609e+06
# reservedPerShare           3.41
# esp                         2.6
# bvps                      11.18
# pb                         2.88
# timeToMarket           19931112
# Name: 000333, dtype: object)
# ('000338', name                       潍柴动力
# industry                   汽车配件
# area                         山东
# pe                        28.63
# outstanding              209217
# totals                   399862
# totalAssets         1.19774e+07
# liquidAssets        6.24249e+06
# fixedAssets         2.30701e+06
# reserved                  20990
# reservedPerShare           0.05
# esp                       0.261
# bvps                       7.86
# pb                         1.27
# timeToMarket           20070430
# Name: 000338, dtype: object)
# ('000400', name                       许继电气
# industry                   电气设备
# area                         河南
# pe                        86.73
# outstanding             73749.9
# totals                   100833
# totalAssets         1.06338e+06
# liquidAssets             923823
# fixedAssets             97789.8
# reserved                82976.4
# reservedPerShare           0.82
# esp                       0.164
# bvps                       5.69
# pb                         3.33
# timeToMarket           19970418
# Name: 000400, dtype: object)
# ('000401', name                       冀东水泥
# industry                     水泥
# area                         河北
# pe                            0
# outstanding              134712
# totals                   134752
# totalAssets         4.41369e+06
# liquidAssets        1.09183e+06
# fixedAssets          2.4322e+06
# reserved                 492000
# reservedPerShare           3.65
# esp                      -0.448
# bvps                       8.25
# pb                         1.41
# timeToMarket           19960614
# Name: 000401, dtype: object)
# ('000402', name                      金 融 街
# industry                   全国地产
# area                         北京
# pe                        28.29
# outstanding              298700
# totals                   298893
# totalAssets         1.04767e+07
# liquidAssets        8.34922e+06
# fixedAssets              281202
# reserved                 688426
# reservedPerShare            2.3
# esp                       0.339
# bvps                       8.11
# pb                         1.58
# timeToMarket           19960626
# Name: 000402, dtype: object)
# ('000403', name                    ST生化
# industry                生物制药
# area                      江西
# pe                     90.45
# outstanding          18176.3
# totals               27257.8
# totalAssets           123196
# liquidAssets         38405.3
# fixedAssets          59799.5
# reserved               11393
# reservedPerShare        0.42
# esp                    0.248
# bvps                     1.8
# pb                     16.65
# timeToMarket        19960628
# Name: 000403, dtype: object)
# ('000404', name                    华意压缩
# industry                专用机械
# area                      江西
# pe                     22.05
# outstanding          39762.2
# totals               55962.4
# totalAssets           684345
# liquidAssets          504763
# fixedAssets           123510
# reserved              110348
# reservedPerShare        1.97
# esp                    0.325
# bvps                    3.94
# pb                      2.43
# timeToMarket        19960619
# Name: 000404, dtype: object)
# ('000407', name                    胜利股份
# industry                  塑料
# area                      山东
# pe                    223.62
# outstanding          66144.6
# totals               77404.9
# totalAssets           407173
# liquidAssets          184017
# fixedAssets          64707.9
# reserved             49380.1
# reservedPerShare        0.64
# esp                    0.027
# bvps                    2.31
# pb                      3.51
# timeToMarket        19960703
# Name: 000407, dtype: object)
# ('000408', name                     金谷源
# industry                商贸代理
# area                      河北
# pe                         0
# outstanding          25230.1
# totals               25230.2
# totalAssets          51679.6
# liquidAssets         41927.1
# fixedAssets          2065.67
# reserved             14367.8
# reservedPerShare        0.57
# esp                   -0.026
# bvps                    0.51
# pb                     40.43
# timeToMarket        19960628
# Name: 000408, dtype: object)
# ('000409', name                    山东地矿
# industry                  普钢
# area                      山东
# pe                    273.87
# outstanding          35758.9
# totals               47270.9
# totalAssets           484041
# liquidAssets          153915
# fixedAssets          92422.7
# reserved             46365.1
# reservedPerShare        0.98
# esp                    0.034
# bvps                    2.22
# pb                      5.61
# timeToMarket        19960627
# Name: 000409, dtype: object)
# ('000410', name                       沈阳机床
# industry                   机床制造
# area                         辽宁
# pe                            0
# outstanding             73982.4
# totals                  76547.1
# totalAssets         2.18654e+06
# liquidAssets        1.83292e+06
# fixedAssets              189021
# reserved                 124626
# reservedPerShare           1.63
# esp                      -0.614
# bvps                       2.91
# pb                         8.71
# timeToMarket           19960718
# Name: 000410, dtype: object)
# ('000411', name                    英特集团
# industry                医药商业
# area                      浙江
# pe                      77.6
# outstanding          20733.1
# totals                 20745
# totalAssets           677322
# liquidAssets          618404
# fixedAssets          26715.6
# reserved             3631.68
# reservedPerShare        0.18
# esp                    0.266
# bvps                    3.17
# pb                      8.68
# timeToMarket        19960716
# Name: 000411, dtype: object)
# ('000413', name                       东旭光电
# industry                    元器件
# area                         河北
# pe                        34.06
# outstanding              201930
# totals                   383510
# totalAssets         1.70513e+06
# liquidAssets         1.1433e+06
# fixedAssets              269127
# reserved                 292502
# reservedPerShare           0.76
# esp                       0.206
# bvps                       2.62
# pb                         3.57
# timeToMarket           19960925
# Name: 000413, dtype: object)
# ('000415', name                       渤海租赁
# industry                   多元金融
# area                         新疆
# pe                        24.99
# outstanding              311554
# totals                   354861
# totalAssets         1.03486e+07
# liquidAssets         1.8814e+06
# fixedAssets         4.39324e+06
# reserved                 391942
# reservedPerShare            1.1
# esp                       0.273
# bvps                       3.09
# pb                         2.95
# timeToMarket           19960716
# Name: 000415, dtype: object)
# ('000416', name                    民生控股
# industry                  百货
# area                      山东
# pe                         0
# outstanding            53161
# totals               53187.1
# totalAssets           127221
# liquidAssets         61263.9
# fixedAssets          4708.62
# reserved             1330.87
# reservedPerShare        0.03
# esp                   -0.034
# bvps                    1.56
# pb                      6.52
# timeToMarket        19960719
# Name: 000416, dtype: object)
# ('000417', name                    合肥百货
# industry                  百货
# area                      安徽
# pe                     31.31
# outstanding          77861.1
# totals               77988.4
# totalAssets           785793
# liquidAssets          445217
# fixedAssets           102843
# reserved             30882.3
# reservedPerShare         0.4
# esp                    0.279
# bvps                    4.27
# pb                      2.73
# timeToMarket        19960812
# Name: 000417, dtype: object)
# ('000418', name                       小天鹅Ａ
# industry                   家用电器
# area                         江苏
# pe                        16.42
# outstanding             43774.7
# totals                  63248.8
# totalAssets          1.2585e+06
# liquidAssets        1.10355e+06
# fixedAssets              100614
# reserved                 115599
# reservedPerShare           1.83
# esp                       1.084
# bvps                       7.66
# pb                          3.1
# timeToMarket           19970328
# Name: 000418, dtype: object)
# ('000419', name                    通程控股
# industry                  百货
# area                      湖南
# pe                     40.36
# outstanding            54329
# totals               54358.3
# totalAssets           371427
# liquidAssets          190857
# fixedAssets           108570
# reserved             41739.5
# reservedPerShare        0.77
# esp                    0.175
# bvps                    3.38
# pb                      2.79
# timeToMarket        19960816
# Name: 000419, dtype: object)
# ('000420', name                    吉林化纤
# industry                  化纤
# area                      吉林
# pe                    495.45
# outstanding          31830.7
# totals               71660.3
# totalAssets           265372
# liquidAssets          115432
# fixedAssets          83830.6
# reserved                   0
# reservedPerShare           0
# esp                    0.012
# bvps                    1.39
# pb                       5.6
# timeToMarket        19960802
# Name: 000420, dtype: object)
# ('000421', name                    南京中北
# industry                公共交通
# area                      江苏
# pe                     33.51
# outstanding          35166.7
# totals               57264.7
# totalAssets           571814
# liquidAssets          193778
# fixedAssets           257956
# reserved             40502.2
# reservedPerShare        0.71
# esp                    0.218
# bvps                    3.76
# pb                      2.59
# timeToMarket        19960806
# Name: 000421, dtype: object)
# ('000422', name                       湖北宜化
# industry                   农药化肥
# area                         湖北
# pe                       159.75
# outstanding             89781.3
# totals                  89786.7
# totalAssets         3.83917e+06
# liquidAssets        1.22371e+06
# fixedAssets         1.82533e+06
# reserved                 179477
# reservedPerShare              2
# esp                       0.038
# bvps                       7.51
# pb                         1.07
# timeToMarket           19960815
# Name: 000422, dtype: object)
# ('000423', name                    东阿阿胶
# industry                 中成药
# area                      山东
# pe                     23.62
# outstanding          65371.9
# totals               65402.1
# totalAssets           818646
# liquidAssets          610667
# fixedAssets           128459
# reserved             69777.2
# reservedPerShare        1.07
# esp                    1.727
# bvps                    9.96
# pb                      5.46
# timeToMarket        19960729
# Name: 000423, dtype: object)
# ('000425', name                       徐工机械
# industry                   工程机械
# area                         江苏
# pe                      1879.94
# outstanding              706951
# totals                   708429
# totalAssets         4.77422e+06
# liquidAssets        3.59924e+06
# fixedAssets              720367
# reserved                 418233
# reservedPerShare           0.59
# esp                       0.002
# bvps                          3
# pb                         1.46
# timeToMarket           19960828
# Name: 000425, dtype: object)
# ('000426', name                    兴业矿业
# industry                 小金属
# area                      内蒙
# pe                    287.52
# outstanding          96326.5
# totals                119389
# totalAssets           391273
# liquidAssets         53572.3
# fixedAssets           136052
# reserved             83932.9
# reservedPerShare         0.7
# esp                    0.018
# bvps                    2.31
# pb                      3.06
# timeToMarket        19960828
# Name: 000426, dtype: object)
# ('000428', name                    华天酒店
# industry                酒店餐饮
# area                      湖南
# ...
# liquidAssets          340731
# fixedAssets           186432
# reserved               70742
# reservedPerShare        0.84
# esp                     0.79
# bvps                    5.64
# pb                      4.45
# timeToMarket        20120810
# Name: 603766, dtype: object)
# ('603788', name                    宁波高发
# industry                汽车配件
# area                      浙江
# pe                     52.91
# outstanding             3420
# totals                 14097
# totalAssets          88117.1
# liquidAssets         74346.7
# fixedAssets          11015.7
# reserved             29877.6
# reservedPerShare        2.12
# esp                     0.62
# bvps                    4.98
# pb                      8.26
# timeToMarket        20150120
# Name: 603788, dtype: object)
# ('603789', name                    星光农机
# industry                农用机械
# area                      浙江
# pe                     75.39
# outstanding             5000
# totals                 20000
# totalAssets           122251
# liquidAssets         93697.3
# fixedAssets          19971.5
# reserved             57458.9
# reservedPerShare        2.87
# esp                    0.477
# bvps                    5.23
# pb                      9.16
# timeToMarket        20150427
# Name: 603789, dtype: object)
# ('603799', name                    华友钴业
# industry                 小金属
# area                      浙江
# pe                         0
# outstanding             9100
# totals                 53519
# totalAssets           975188
# liquidAssets          559737
# fixedAssets           231758
# reserved              121737
# reservedPerShare        2.27
# esp                   -0.054
# bvps                    4.82
# pb                      5.76
# timeToMarket        20150129
# Name: 603799, dtype: object)
# ('603800', name                    道森股份
# industry                专用机械
# area                      江苏
# pe                    221.87
# outstanding             5200
# totals                 20800
# totalAssets          86552.7
# liquidAssets               0
# fixedAssets                0
# reserved                   0
# reservedPerShare           0
# esp                    0.152
# bvps                    3.08
# pb                     14.64
# timeToMarket        20151210
# Name: 603800, dtype: object)
# ('603806', name                     福斯特
# industry                  塑料
# area                      浙江
# pe                     35.31
# outstanding             9021
# totals                 40200
# totalAssets           464632
# liquidAssets          401357
# fixedAssets            38415
# reserved              151183
# reservedPerShare        3.76
# esp                    1.029
# bvps                   10.04
# pb                      4.83
# timeToMarket        20140905
# Name: 603806, dtype: object)
# ('603808', name                     歌力思
# industry                  服饰
# area                      深圳
# pe                     62.68
# outstanding             4000
# totals               16564.9
# totalAssets           178295
# liquidAssets          138846
# fixedAssets          21960.2
# reserved              105067
# reservedPerShare        6.34
# esp                     0.74
# bvps                      10
# pb                       5.3
# timeToMarket        20150422
# Name: 603808, dtype: object)
# ('603818', name                    曲美家居
# industry                家居用品
# area                      北京
# pe                     97.54
# outstanding            12104
# totals                 48412
# totalAssets           147310
# liquidAssets         86318.2
# fixedAssets          38024.5
# reserved               32885
# reservedPerShare        0.68
# esp                     0.18
# bvps                    2.45
# pb                      9.14
# timeToMarket        20150422
# Name: 603818, dtype: object)
# ('603828', name                     柯利达
# industry                装修装饰
# area                      江苏
# pe                     75.74
# outstanding             3000
# totals               12378.5
# totalAssets           221921
# liquidAssets          204418
# fixedAssets           9302.7
# reserved             60415.7
# reservedPerShare        4.88
# esp                     0.37
# bvps                     8.6
# pb                      4.04
# timeToMarket        20150226
# Name: 603828, dtype: object)
# ('603838', name                    四通股份
# industry                  陶瓷
# area                      广东
# pe                     95.27
# outstanding             3334
# totals                 13334
# totalAssets          68222.2
# liquidAssets         48977.6
# fixedAssets             9719
# reserved             27323.5
# reservedPerShare        2.05
# esp                     0.38
# bvps                     4.6
# pb                      9.14
# timeToMarket        20150701
# Name: 603838, dtype: object)
# ('603866', name                    桃李面包
# industry                  食品
# area                      辽宁
# pe                     35.69
# outstanding          4501.25
# totals               45012.6
# totalAssets           151965
# liquidAssets         52926.9
# fixedAssets          62875.9
# reserved               749.2
# reservedPerShare        0.02
# esp                    0.554
# bvps                    2.98
# pb                      8.85
# timeToMarket        20151222
# Name: 603866, dtype: object)
# ('603869', name                    北部湾旅
# industry                旅游服务
# area                      广西
# pe                     53.59
# outstanding             5406
# totals                 21624
# totalAssets          94701.2
# liquidAssets         38755.4
# fixedAssets            44386
# reserved             30624.6
# reservedPerShare        1.42
# esp                     0.39
# bvps                    3.58
# pb                      7.19
# timeToMarket        20150326
# Name: 603869, dtype: object)
# ('603883', name                     老百姓
# industry                医药商业
# area                      湖南
# pe                     86.78
# outstanding             6700
# totals                 26700
# totalAssets           357857
# liquidAssets          252361
# fixedAssets          18555.7
# reserved              108511
# reservedPerShare        4.06
# esp                     0.69
# bvps                    8.02
# pb                      8.86
# timeToMarket        20150423
# Name: 603883, dtype: object)
# ('603885', name                       吉祥航空
# industry                     空运
# area                         上海
# pe                        32.86
# outstanding                6800
# totals                    56800
# totalAssets         1.19277e+06
# liquidAssets             296002
# fixedAssets              423470
# reserved                 113512
# reservedPerShare              2
# esp                        1.83
# bvps                       6.39
# pb                        11.73
# timeToMarket           20150527
# Name: 603885, dtype: object)
# ('603889', name                    新澳股份
# industry                  纺织
# area                      浙江
# pe                     33.88
# outstanding             4002
# totals                 16231
# totalAssets           141220
# liquidAssets         89417.4
# fixedAssets          32279.3
# reserved             37984.1
# reservedPerShare        2.34
# esp                    0.698
# bvps                    6.55
# pb                      4.82
# timeToMarket        20141231
# Name: 603889, dtype: object)
# ('603898', name                     好莱客
# industry                家居用品
# area                      广东
# pe                     66.85
# outstanding             7350
# totals                 29400
# totalAssets           107359
# liquidAssets         58980.1
# fixedAssets            38106
# reserved             22899.3
# reservedPerShare        0.78
# esp                     0.38
# bvps                    3.03
# pb                     10.55
# timeToMarket        20150217
# Name: 603898, dtype: object)
# ('603899', name                    晨光文具
# industry                文教休闲
# area                      上海
# pe                     41.29
# outstanding             6000
# totals                 46000
# totalAssets           258952
# liquidAssets          167937
# fixedAssets          62167.7
# reserved             73275.3
# reservedPerShare        1.59
# esp                     0.72
# bvps                     4.5
# pb                      8.65
# timeToMarket        20150127
# Name: 603899, dtype: object)
# ('603901', name                    永创智能
# industry                专用机械
# area                      浙江
# pe                     82.37
# outstanding             5000
# totals                 20000
# totalAssets           123899
# liquidAssets          100112
# fixedAssets          19940.2
# reserved             46188.3
# reservedPerShare        2.31
# esp                    0.292
# bvps                    4.01
# pb                      8.01
# timeToMarket        20150529
# Name: 603901, dtype: object)
# ('603918', name                    金桥信息
# industry                软件服务
# area                      上海
# pe                    774.11
# outstanding             2200
# totals                  8800
# totalAssets          71303.9
# liquidAssets         64361.2
# fixedAssets          5576.68
# reserved             20950.4
# reservedPerShare        2.38
# esp                     0.09
# bvps                    4.93
# pb                     17.02
# timeToMarket        20150528
# Name: 603918, dtype: object)
# ('603936', name                    博敏电子
# industry                 元器件
# area                      广东
# pe                    104.12
# outstanding             4185
# totals                 16735
# totalAssets           150374
# liquidAssets         59964.4
# fixedAssets                0
# reserved                   0
# reservedPerShare           0
# esp                    0.263
# bvps                    4.56
# pb                         8
# timeToMarket        20151209
# Name: 603936, dtype: object)
# ('603939', name                    益丰药房
# industry                医药商业
# area                      湖南
# pe                     80.82
# outstanding             8000
# totals                 32000
# totalAssets           231794
# liquidAssets          175938
# fixedAssets          21992.9
# reserved             88311.3
# reservedPerShare        2.76
# esp                    0.391
# bvps                    4.25
# pb                      9.92
# timeToMarket        20150217
# Name: 603939, dtype: object)
# ('603968', name                    醋化股份
# industry                化工原料
# area                      江苏
# pe                      52.5
# outstanding             5112
# totals                 20448
# totalAssets           169404
# liquidAssets          102408
# fixedAssets          56554.7
# reserved             39697.4
# reservedPerShare        1.94
# esp                      0.5
# bvps                    5.23
# pb                      5.76
# timeToMarket        20150518
# Name: 603968, dtype: object)
# ('603969', name                    银龙股份
# industry                其他建材
# area                      天津
# pe                     58.56
# outstanding            10000
# totals                 40000
# totalAssets           158057
# liquidAssets          119814
# fixedAssets          19196.8
# reserved             67153.4
# reservedPerShare        1.68
# esp                     0.25
# bvps                    3.69
# pb                      5.14
# timeToMarket        20150227
# Name: 603969, dtype: object)
# ('603979', name                     金诚信
# industry                建筑施工
# area                      北京
# pe                     48.42
# outstanding             9500
# totals                 37500
# totalAssets           451674
# liquidAssets          360596
# fixedAssets          74966.8
# reserved              181955
# reservedPerShare        4.85
# esp                     0.61
# bvps                    9.36
# pb                       3.5
# timeToMarket        20150630
# Name: 603979, dtype: object)
# ('603988', name                    中电电机
# industry                电气设备
# area                      江苏
# pe                     96.39
# outstanding             2240
# totals                  8000
# totalAssets          80292.2
# liquidAssets         68467.8
# fixedAssets          8074.96
# reserved             32804.3
# reservedPerShare         4.1
# esp                    0.445
# bvps                    7.85
# pb                      7.29
# timeToMarket        20141104
# Name: 603988, dtype: object)
# ('603989', name                    艾华集团
# industry                 元器件
# area                      湖南
# pe                     55.79
# outstanding             7500
# totals                 30000
# totalAssets           216400
# liquidAssets          163267
# fixedAssets          44205.9
# reserved              102641
# reservedPerShare        3.42
# esp                    0.495
# bvps                     5.5
# pb                      6.69
# timeToMarket        20150515
# Name: 603989, dtype: object)
# ('603993', name                       洛阳钼业
# industry                    小金属
# area                         河南
# pe                        91.89
# outstanding         1.29537e+06
# totals              1.68872e+06
# totalAssets         3.01662e+06
# liquidAssets        1.48749e+06
# fixedAssets              431346
# reserved            1.29719e+06
# reservedPerShare           0.77
# esp                       0.038
# bvps                       1.03
# pb                         4.54
# timeToMarket           20121009
# Name: 603993, dtype: object)
# ('603996', name                    中新科技
# industry                电脑设备
# area                      浙江
# pe                     37.53
# outstanding             5010
# totals                 20010
# totalAssets           221192
# liquidAssets          189214
# fixedAssets                0
# reserved                   0
# reservedPerShare           0
# esp                    0.403
# bvps                    5.64
# pb                      3.58
# timeToMarket        20151222
# Name: 603996, dtype: object)
# ('603997', name                    继峰股份
# industry                汽车配件
# area                      浙江
# pe                     67.99
# outstanding             6000
# totals                 42000
# totalAssets           145513
# liquidAssets         91620.2
# fixedAssets          42190.8
# reserved             40594.5
# reservedPerShare        0.97
# esp                     0.32
# bvps                    3.06
# pb                       9.1
# timeToMarket        20150302
# Name: 603997, dtype: object)
# ('603998', name                    方盛制药
# industry                 中成药
# area                      湖南
# pe                     74.85
# outstanding          8972.57
# totals               14173.2
# totalAssets          98741.4
# liquidAssets         63987.1
# fixedAssets          21054.2
# reserved             39710.6
# reservedPerShare         2.8
# esp                    0.514
# bvps                    6.12
# pb                      8.38
# timeToMarket        20141205
# Name: 603998, dtype: object)
# ('603999', name                    读者传媒
# industry                 出版业
# area                      甘肃
# pe                    115.17
# outstanding             6000
# totals                 24000
# totalAssets           142542
# liquidAssets               0
# fixedAssets                0
# reserved                   0
# reservedPerShare           0
# esp                    0.261
# bvps                    5.82
# pb                       6.9
# timeToMarket        20151210
# Name: 603999, dtype: object)
# ('600656', name                   *ST博元
# industry                 综合类
# area                      广东
# pe                         0
# outstanding          19032.8
# totals               19034.4
# totalAssets            11922
# liquidAssets          2465.8
# fixedAssets             2.72
# reserved             19593.1
# reservedPerShare        1.03
# esp                     -0.1
# bvps                    -2.1
# pb                         0
# timeToMarket        19901219
# Name: 600656, dtype: object)
# ('603299', name                   井神股份
# industry               化工原料
# area                     江苏
# pe                        0
# outstanding               0
# totals                    0
# totalAssets          429644
# liquidAssets         111085
# fixedAssets          273594
# reserved            68416.6
# reservedPerShare          0
# esp                       0
# bvps                      0
# pb                        0
# timeToMarket              0
# Name: 603299, dtype: object)
# ('603778', name                   乾景园林
# industry               装修装饰
# area                     北京
# pe                        0
# outstanding               0
# totals                    0
# totalAssets         87105.8
# liquidAssets        83184.9
# fixedAssets         1056.64
# reserved            12976.8
# reservedPerShare          0
# esp                       0
# bvps                      0
# pb                        0
# timeToMarket              0
# Name: 603778, dtype: object)

# %%
basics
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>industry</th>
#       <th>area</th>
#       <th>pe</th>
#       <th>outstanding</th>
#       <th>totals</th>
#       <th>totalAssets</th>
#       <th>liquidAssets</th>
#       <th>fixedAssets</th>
#       <th>reserved</th>
#       <th>reservedPerShare</th>
#       <th>esp</th>
#       <th>bvps</th>
#       <th>pb</th>
#       <th>timeToMarket</th>
#     </tr>
#     <tr>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>000001</th>
#       <td>平安银行</td>
#       <td>银行</td>
#       <td>深圳</td>
#       <td>7.51</td>
#       <td>1180405.50</td>
#       <td>1430867.63</td>
#       <td>2.599060e+08</td>
#       <td>0.00</td>
#       <td>440600.00</td>
#       <td>5932600.00</td>
#       <td>4.15</td>
#       <td>1.270</td>
#       <td>10.98</td>
#       <td>1.13</td>
#       <td>19910403</td>
#     </tr>
#     <tr>
#       <th>000002</th>
#       <td>万  科Ａ</td>
#       <td>全国地产</td>
#       <td>深圳</td>
#       <td>29.50</td>
#       <td>970678.75</td>
#       <td>1103713.00</td>
#       <td>5.707935e+07</td>
#       <td>52000132.00</td>
#       <td>404016.41</td>
#       <td>834236.94</td>
#       <td>0.76</td>
#       <td>0.621</td>
#       <td>8.05</td>
#       <td>3.04</td>
#       <td>19910129</td>
#     </tr>
#     <tr>
#       <th>000004</th>
#       <td>国农科技</td>
#       <td>生物制药</td>
#       <td>深圳</td>
#       <td>1310.21</td>
#       <td>8387.54</td>
#       <td>8397.66</td>
#       <td>3.586395e+04</td>
#       <td>28597.28</td>
#       <td>3792.01</td>
#       <td>66.45</td>
#       <td>0.01</td>
#       <td>0.028</td>
#       <td>0.99</td>
#       <td>50.18</td>
#       <td>19910114</td>
#     </tr>
#     <tr>
#       <th>000005</th>
#       <td>世纪星源</td>
#       <td>区域地产</td>
#       <td>深圳</td>
#       <td>0.00</td>
#       <td>91374.29</td>
#       <td>91433.35</td>
#       <td>1.336589e+05</td>
#       <td>22092.81</td>
#       <td>2413.78</td>
#       <td>26976.98</td>
#       <td>0.30</td>
#       <td>-0.033</td>
#       <td>0.70</td>
#       <td>14.82</td>
#       <td>19901210</td>
#     </tr>
#     <tr>
#       <th>000006</th>
#       <td>深振业Ａ</td>
#       <td>区域地产</td>
#       <td>深圳</td>
#       <td>44.11</td>
#       <td>134148.73</td>
#       <td>134999.50</td>
#       <td>1.238693e+06</td>
#       <td>1015396.63</td>
#       <td>362.29</td>
#       <td>48432.15</td>
#       <td>深天地Ａ</td>
#       <td>建筑施工</td>
#       <td>深圳</td>
#       <td>116.62</td>

# %% [markdown]
# # Test

# %%
import matplotlib 
# %matplotlib inline

import sqlalchemy as sa
import pandas as pd
import numpy as np


engine = sa.create_engine('mysql+mysqldb://root:eth@2002@localhost/darwin')

connection = engine.connect()


    
output = pd.read_sql(sa.text('SELECT date, close FROM Stock_Price_Daily where code=:col1'), engine, params={'col1': 'sh600100'})
output1 = pd.DataFrame(np.array(output.close), index=output.date, columns=['close'])

output2 = pd.read_sql(sa.text('SELECT DISTINCT code FROM Stock_Price_Daily'), engine)
#output.plot()
#ts.get_h_data('002337', start='2013-01-01') #前复权
#ts.get_h_data('002337', autype='hfq') #后复权
#ts.get_h_data('002337', autype=None) #不复权
#ts.get_h_data('002337', start='2015-01-01', end='2015-03-16') #两个日期之间的前复权数据

#ts.get_h_data('399106', index=True) #深圳综合指数

# %%
output2
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sh600000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>sh600001</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>sh600002</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sh600003</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>sh600004</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sh600005</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>sh600006</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>sh600007</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>sh600008</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>sh600009</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>sh600010</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>sh600011</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>sh600012</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>sh600015</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>sh600016</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>sh600017</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>sh600018</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>sh600019</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>sh600020</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>sh600021</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>sh600022</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>sh600023</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>sh600026</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>sh600027</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>sh600028</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>sh600029</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>sh600030</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>sh600031</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>sh600033</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>sh600035</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2867</th>
#       <td>sz300467</td>
#     </tr>
#     <tr>
#       <th>2868</th>
#       <td>sz300468</td>
#     </tr>
#     <tr>
#       <th>2869</th>
#       <td>sz300469</td>
#     </tr>
#     <tr>
#       <th>2870</th>
#       <td>sz300470</td>
#     </tr>
#     <tr>
#       <th>2871</th>
#       <td>sz300471</td>
#     </tr>
#     <tr>
#       <th>2872</th>
#       <td>sz300472</td>
#     </tr>
#     <tr>
#       <th>2873</th>
#       <td>sz300473</td>
#     </tr>
#     <tr>
#       <th>2874</th>
#       <td>sz300475</td>
#     </tr>
#     <tr>
#       <th>2875</th>
#       <td>sz300476</td>
#     </tr>
#     <tr>
#       <th>2876</th>
#       <td>sz300477</td>
#     </tr>
#     <tr>
#       <th>2877</th>
#       <td>sz300478</td>
#     </tr>
#     <tr>
#       <th>2878</th>
#       <td>sz300479</td>
#     </tr>
#     <tr>
#       <th>2879</th>
#       <td>sz300480</td>
#     </tr>
#     <tr>
#       <th>2880</th>
#       <td>sz300481</td>
#     </tr>
#     <tr>
#       <th>2881</th>
#       <td>sz300482</td>
#     </tr>
#     <tr>
#       <th>2882</th>
#       <td>sz300483</td>
#     </tr>
#     <tr>
#       <th>2883</th>
#       <td>sz300485</td>
#     </tr>
#     <tr>
#       <th>2884</th>
#       <td>sz300486</td>
#     </tr>
#     <tr>
#       <th>2885</th>
#       <td>sz300487</td>
#     </tr>
#     <tr>
#       <th>2886</th>
#       <td>sz300488</td>
#     </tr>
#     <tr>
#       <th>2887</th>
#       <td>sz300489</td>
#     </tr>
#     <tr>
#       <th>2888</th>
#       <td>sz300490</td>
#     </tr>
#     <tr>
#       <th>2889</th>
#       <td>sz300491</td>
#     </tr>
#     <tr>
#       <th>2890</th>
